# %% [markdown]
# Data Bootcamp
#
# Spring 2018
#
# Nan Jiang
#
# HW 3

# %% [markdown]
# **Question #1: Enter and run this code in a Jupyter cell to produce the dataframe weo:**

# %%
import pandas as pd
data = {'BRA': [13.37, 13.30, 14.34, 15.07, 15.46, 15.98, 16.10],
        'JPN': [33.43, 31.83, 33.71, 34.29, 35.60, 36.79, 37.39],
        'USA': [48.30, 46.91, 48.31, 49.72, 51.41, 52.94, 54.60],
        'Year': [2008, 2009, 2010, 2011, 2012, 2013, 2014]}
weo  = pd.DataFrame(data)

# %% [markdown]
# The numbers are GDP per person in thousands of US dollars, 2008 to 2014, variable PPPPC in the IMF’s World Economic Outlook database.

# %% [markdown]
# **a. Explain the import statement.**

# %% [markdown]
# Answer:
#
# The import statement imports the package pandas, but under the abbreviation pd. Package refers to plug-ins or extensions that expand Python's capabilities.

# %% [markdown]
# **b. What type of object is data?**

# %%
type(data)
# Out:
# dict

# %% [markdown]
# Answer:
#
# Data is a dictionary.

# %% [markdown]
# **c. Why does the last line have pd prior to the DataFrame function?**

# %% [markdown]
# **Answer:**
#
# DataFrame is a function in package pandas. For function foo in package xyz, foo is executed under syntax of xyz.foo(), which is why we have pd.DataFrame in this example.

# %% [markdown]
# **d. What type of object is weo?**

# %%
type(weo)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# **Answer:**:
#
# weo is a dataframe.

# %% [markdown]
# **e. How many rows does it have? Columns?**

# %%
weo.shape
# Out:
# (7, 4)

# %% [markdown]
# **Answer:**
#
# It has 7 rows and 4 columns.

# %% [markdown]
# **f. What dtypes are the variables/columns? What does this mean?**

# %%
weo.dtypes
# Out:
# BRA     float64
# JPN     float64
# USA     float64
# Year      int64
# dtype: object

# %% [markdown]
# **Answer:**
#
# BRA JPN and USA are floats, while Year is an integer. Just like what we learnt before, floats are datastructure involving number with digits whereas integers are integers, number without digits. In this case, variables under the country names are GDP per person and are naturally floats, whereas number denoting year, is naturally integers.

# %% [markdown]
# **g. Challenging. What are each of these expressions? What type?**

# %%
weo['Year']
# Out:
# 0    2008
# 1    2009
# 2    2010
# 3    2011
# 4    2012
# 5    2013
# 6    2014
# Name: Year, dtype: int64

# %%
type(weo['Year'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# **Answer:**
#
# This expression specifies and extracts the column (Year) we want to look at. The expression is a series, which is essentially a DataFrame with a single variable or column.

# %%
weo[['Year']]
# Out:
#    Year
# 0  2008
# 1  2009
# 2  2010
# 3  2011
# 4  2012
# 5  2013
# 6  2014

# %%
type(weo[['Year']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# **Answer:**
#
# This double square bracket expression is normally used to extra multiple columns and turn them into a dataframe. Since only one variable, namely "Year", is in the brackets, a dataframe with one columns is returned. This expression generates a dataframe.

# %%
weo[[3]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-417-5a76019d91f2> in <module>()
# ----> 1 weo[[3]]
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2131         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2132             # either boolean or fancy integer index
# -> 2133             return self._getitem_array(key)
#    2134         elif isinstance(key, DataFrame):
#    2135             return self._getitem_frame(key)
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2175             return self._take(indexer, axis=0, convert=False)
#    2176         else:
# -> 2177             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2178             return self._take(indexer, axis=1, convert=True)
#    2179
#
# ...

# %%
type(weo[[3]])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-418-b85a8f7e505e> in <module>()
# ----> 1 type(weo[[3]])
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2131         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2132             # either boolean or fancy integer index
# -> 2133             return self._getitem_array(key)
#    2134         elif isinstance(key, DataFrame):
#    2135             return self._getitem_frame(key)
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2175             return self._take(indexer, axis=0, convert=False)
#    2176         else:
# -> 2177             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2178             return self._take(indexer, axis=1, convert=True)
#    2179
#
# ...

# %% [markdown]
# **Answer:**
#
# This expression returns error: "[3] not in index".

# %% [markdown]
# **h. Challenging. Find and apply a method to convert weo['Year'] to type float. Hint: The method begins with the letter a.**

# %%
a = weo['Year']
a.astype(float)
# Out:
# 0    2008.0
# 1    2009.0
# 2    2010.0
# 3    2011.0
# 4    2012.0
# 5    2013.0
# 6    2014.0
# Name: Year, dtype: float64

# %% [markdown]
# **i. Describe the result of the statement t = weo.tail(3). What kind of object is t? What does it look like?**

# %%
t = weo.tail(3)
t
# Out:
#      BRA    JPN    USA  Year
# 4  15.46  35.60  51.41  2012
# 5  15.98  36.79  52.94  2013
# 6  16.10  37.39  54.60  2014

# %%
type(t)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# **Answer:**
#
# The result gives the last three rows of dataframe weo. It is still a dataframe.

# %% [markdown]
# **j. How would you create a new dataframe that consists of the first 4 rows of weo?**

# %%
h = weo.head(4)
h
# Out:
#      BRA    JPN    USA  Year
# 0  13.37  33.43  48.30  2008
# 1  13.30  31.83  46.91  2009
# 2  14.34  33.71  48.31  2010
# 3  15.07  34.29  49.72  2011

# %% [markdown]
# **k. What type of object is weo['BRA']?**

# %%
type(weo['BRA'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# **Answer:**
#
# It is a series.

# %% [markdown]
# **l. Create a new variable equal to the ratio of Brazil’s GDP per capita to Japan’s and add it to the DataFrame.**

# %%
weo["BJ_ratio"] = weo["BRA"]/weo["JPN"]
ratio
# Out:
# 0    0.399940
# 1    0.417845
# 2    0.425393
# 3    0.439487
# 4    0.434270
# 5    0.434357
# 6    0.430596
# dtype: float64

# %%
print("\n", weo)
# Out:
#       BRA    JPN    USA  Year  BJ_ratio
# 0  13.37  33.43  48.30  2008  0.399940
# 1  13.30  31.83  46.91  2009  0.417845
# 2  14.34  33.71  48.31  2010  0.425393
# 3  15.07  34.29  49.72  2011  0.439487
# 4  15.46  35.60  51.41  2012  0.434270
# 5  15.98  36.79  52.94  2013  0.434357
# 6  16.10  37.39  54.60  2014  0.430596

# %% [markdown]
# **m. Challenging. Use the drop() method to eliminate this (new) variable from the dataframe.**

# %%
weo = weo.drop(["BJ_ratio"],axis=1)
weo
# Out:
#      BRA    JPN    USA  Year
# 0  13.37  33.43  48.30  2008
# 1  13.30  31.83  46.91  2009
# 2  14.34  33.71  48.31  2010
# 3  15.07  34.29  49.72  2011
# 4  15.46  35.60  51.41  2012
# 5  15.98  36.79  52.94  2013
# 6  16.10  37.39  54.60  2014

# %% [markdown]
# **n. What are weo’s row and column labels?**

# %%
weo.index.tolist()
# Out:
# [0, 1, 2, 3, 4, 5, 6]

# %%
weo.columns.tolist()
# Out:
# ['BRA', 'JPN', 'USA', 'Year']

# %% [markdown]
# **Answer:**
#
# Weo's row labels are [0, 1, 2, 3, 4, 5, 6] and columns labels are ['BRA', 'JPN', 'USA', 'Year'].

# %% [markdown]
# **o. Set the index equal to the Year variable.**

# %%
weo.set_index(['Year'], inplace = True)
weo
# Out:
#         BRA    JPN    USA
# Year
# 2008  13.37  33.43  48.30
# 2009  13.30  31.83  46.91
# 2010  14.34  33.71  48.31
# 2011  15.07  34.29  49.72
# 2012  15.46  35.60  51.41
# 2013  15.98  36.79  52.94
# 2014  16.10  37.39  54.60

# %% [markdown]
# **p. Change the names of the other variables to Brazil, Japan, and United States.**

# %%
weo = weo.rename(columns={'BRA': 'Brazil','JPN':'Japan', 'USA':'United States'})
weo
# Out:
#       Brazil  Japan  United States
# Year
# 2008   13.37  33.43          48.30
# 2009   13.30  31.83          46.91
# 2010   14.34  33.71          48.31
# 2011   15.07  34.29          49.72
# 2012   15.46  35.60          51.41
# 2013   15.98  36.79          52.94
# 2014   16.10  37.39          54.60

# %% [markdown]
# **q. Export the dataframe to an Excel spreadsheet.**

# %%
weo.to_excel("weo.xlsx")

# %% [markdown]
# **r. What method would you use to compute the mean for each country? What are the means?**

# %%
weo.mean()
# Out:
# Brazil           14.802857
# Japan            34.720000
# United States    50.312857
# dtype: float64

# %% [markdown]
# **Answer:**
#
# The means for Brazil, Japan and United States are 14.802857, 34.720000 and 50.312857 respectively.

# %% [markdown]
# **s. Challenging. How would you compute means across countries for each year?**

# %%
weo[['Brazil','Japan','United States']].mean(axis=1)
# Out:
# Year
# 2008    31.700000
# 2009    30.680000
# 2010    32.120000
# 2011    33.026667
# 2012    34.156667
# 2013    35.236667
# 2014    36.030000
# dtype: float64

# %% [markdown]
# **t. Plot the data by applying a plot method to weo.**

# %%
import matplotlib.pyplot as plt

# %%
weo.plot()
plt.show()

# %% [markdown]
# **u. Challenging. Change the colors of the lines to green (Brazil), red (Japan), and blue (US).**

# %%
fig, ax = plt.subplots()
weo.plot(ax=ax,kind='line', color=['green', 'red', 'blue'])
plt.show()

# %% [markdown]
# **v. Challenging. Do the same plot with a log scale. Hint: Read the documentation for the
# plot method.**

# %%
fig, ax = plt.subplots()
weo.plot(ax=ax,
         kind='line', color=['green', 'red', 'blue'])
plt.yscale('log')
plt.show()

# %% [markdown]
# **w. Plot Brazil on its own.**

# %%
fig, ax = plt.subplots()
weo['Brazil'].plot(ax=ax, kind='line', color=['green', 'red', 'blue'])
plt.show()

# %% [markdown]
# **Question #2: Use read_csv() to read the responses of a previous semesters entry poll from:**

# %% [markdown]
# **a. Read the file and assign it to the variable ep.**

# %%
url = 'https://raw.githubusercontent.com/NYUDataBootcamp/Materials/master/Data/entry_poll_fall16.csv'
ep = pd.read_csv(url)

# %% [markdown]
# **b. Describe its contents. What are the variables? The responses?**

# %%
ep
# Out:
#               TimeStamp            Why have you enrolled in this course?    \
# 0   2016-08-16 12:55:02                             To help with my career
# 1   2016-08-31 05:54:00                                 I heard it was fun
# 2   2016-09-01 19:43:56                                 I like a challenge
# 3   2016-09-01 20:00:08                                 I heard it was fun
# 4   2016-09-01 20:00:52                                 I heard it was fun
# 5   2016-09-01 20:56:31                                 I heard it was fun
# 6   2016-09-01 22:30:33                             To help with my career
# 7   2016-09-01 22:31:14                             To help with my career
# 8   2016-09-02 01:09:15                        I lost my mind for a minute
# 9   2016-09-02 10:25:48                                 I heard it was fun
# 10  2016-09-02 11:54:33                             To help with my career
# ...

# %% [markdown]
# **Answer:**
#
# This is a survey for the class. It has 10 variables, i.e. survey questions, and 85 rows, i.e. responses.

# %% [markdown]
# **c. What data types are the variables?**

# %%
ep.dtypes
# Out:
# TimeStamp                                                                                              object
# Why have you enrolled in this course?                                                                  object
# What program are you enrolled in?                                                                      object
# How much programming experience have you had?                                                          object
# How much experience with probability and statistics have you had?                                      object
# What is your expected major or concentration?                                                          object
# What career path most interests you?                                                                   object
# Do you use social media for information purposes?  Check all that apply.                               object
# ...

# %% [markdown]
# **Answer:**
#
# The ten variables are all objects.

# %% [markdown]
# **d. Change the variable names to something shorter.**

# %%
ep.columns = ["Time", "Motivation", "Program", "Programming Experience", 
              "Statistics Background", "Expected Major & Minor", "Career Path of Interest",
             "Social Media for Info", "Data of Interest", "Special Topics"]
ep
# Out:
#                    Time                                         Motivation  \
# 0   2016-08-16 12:55:02                             To help with my career
# 1   2016-08-31 05:54:00                                 I heard it was fun
# 2   2016-09-01 19:43:56                                 I like a challenge
# 3   2016-09-01 20:00:08                                 I heard it was fun
# 4   2016-09-01 20:00:52                                 I heard it was fun
# 5   2016-09-01 20:56:31                                 I heard it was fun
# 6   2016-09-01 22:30:33                             To help with my career
# 7   2016-09-01 22:31:14                             To help with my career
# 8   2016-09-02 01:09:15                        I lost my mind for a minute
# 9   2016-09-02 10:25:48                                 I heard it was fun
# 10  2016-09-02 11:54:33                             To help with my career
# ...

# %% [markdown]
# **e. Challenging. Describe what this code does:**

# %%
ep[list(ep)[1]].value_counts()
# Out:
# To help with my career                               60
# I heard it was fun                                   14
# I lost my mind for a minute                           5
# To finish my major                                    1
# I like a challenge                                    1
# i am living in Santiago de Chile                      1
# Wanted to try something completely different          1
# Recommended by a professor.                           1
# I code/build websites in my spare time as a hobby     1
# Name: Motivation, dtype: int64

# %% [markdown]
# **Answer:**
#
# 1. list(ep) turns the columns of ep into a list.
# 2. list(ep)[1] extracts the second variable within the list, which is "Motivation"
# 3. ep[list(ep)[1]] extracts the column of ep specified by code list(ep)[1], namely "Motivation". In other words, it extracts the column "Motivation" from ep as a series.
# 4. ep[list(ep)[1]].value_counts() applies the method value_counts() to series ep[list(ep)[1]]. This method returns object containing counts of unique values, in descending order so that the first element is the most frequently-occurring element. Also, it excludes NA values by default.

# %% [markdown]
# **Question #3: Consider the 538 college majors data at url:**

# %%
url1 = 'https://raw.githubusercontent.com/fivethirtyeight/data/master/'
url2 = 'college-majors/recent-grads.csv'
url = url1 + url2

# %% [markdown]
# **a. Create a dataframe df538 from the csv file at url using read_csv(). What are its dimensions?
# **

# %%
df538 = pd.read_csv(url) 

df538.shape
# Out:
# (173, 21)

# %% [markdown]
# **Answer:**
#
# Its dimension is 173 by 21, i.e. 173 rows and 21 columns.

# %% [markdown]
# **b. What argument/parameter would you use to read only the first ten lines of the file?**

# %%
df538.head(10)
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
# 5     6        2418                        NUCLEAR ENGINEERING   2573.0
# 6     7        6202                          ACTUARIAL SCIENCE   3777.0
# 7     8        5001                 ASTRONOMY AND ASTROPHYSICS   1792.0
# 8     9        2414                     MECHANICAL ENGINEERING  91227.0
# 9    10        2408                     ELECTRICAL ENGINEERING  81527.0
#
#        Men    Women     Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0        Engineering    0.120564           36      1976
# ...

# %% [markdown]
# **c. Extract the variables numbered [2, 4, 15, 16, 17]. What are the names of these variables? What do they represent?**

# %%
df538.iloc[:,2]
# Out:
# 0                              PETROLEUM ENGINEERING
# 1                     MINING AND MINERAL ENGINEERING
# 2                          METALLURGICAL ENGINEERING
# 3          NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4                               CHEMICAL ENGINEERING
# 5                                NUCLEAR ENGINEERING
# 6                                  ACTUARIAL SCIENCE
# 7                         ASTRONOMY AND ASTROPHYSICS
# 8                             MECHANICAL ENGINEERING
# 9                             ELECTRICAL ENGINEERING
# 10                              COMPUTER ENGINEERING
# 11                             AEROSPACE ENGINEERING
# 12                            BIOMEDICAL ENGINEERING
# 13                                 MATERIALS SCIENCE
# 14         ENGINEERING MECHANICS PHYSICS AND SCIENCE
# 15                            BIOLOGICAL ENGINEERING
# 16          INDUSTRIAL AND MANUFACTURING ENGINEERING
# 17                               GENERAL ENGINEERING
# ...

# %%
df538.iloc[:,4]
# Out:
# 0       2057.0
# 1        679.0
# 2        725.0
# 3       1123.0
# 4      21239.0
# 5       2200.0
# 6       2110.0
# 7        832.0
# 8      80320.0
# 9      65511.0
# 10     33258.0
# 11     12953.0
# 12      8407.0
# 13      2949.0
# 14      3526.0
# 15      6062.0
# 16     12453.0
# 17     45683.0
# 18      1835.0
# 19       877.0
# 20     99743.0
# 21         NaN
# 22      8181.0
# 23      2020.0
# 24     13496.0
# 25     41081.0
# 26     16820.0
# 27      7921.0
# 28      7398.0
# 29      2639.0
#         ...
# 143     4897.0
# 144     2049.0
# 145    86648.0
# 146    29909.0
# 147    15670.0
# 148     3240.0
# 149    24786.0
# 150     5166.0
# 151     5137.0
# 152     5347.0
# 153     4133.0
# 154     2734.0
# 155     1936.0
# 156      885.0
# 157     2013.0
# 158    18616.0
# 159     4754.0
# 160     4364.0
# 161      404.0
# 162    11376.0
# 163     1225.0
# 164     1167.0
# 165     3472.0
# 166    14440.0
# 167     7022.0
# 168     3050.0
# 169      522.0
# 170      568.0
# ...

# %%
df538.iloc[:,15:18]
# Out:
#      Median  P25th   P75th
# 0    110000  95000  125000
# 1     75000  55000   90000
# 2     73000  50000  105000
# 3     70000  43000   80000
# 4     65000  50000   75000
# 5     65000  50000  102000
# 6     62000  53000   72000
# 7     62000  31500  109000
# 8     60000  48000   70000
# 9     60000  45000   72000
# 10    60000  45000   75000
# 11    60000  42000   70000
# 12    60000  36000   70000
# 13    60000  39000   65000
# 14    58000  25000   74000
# 15    57100  40000   76000
# 16    57000  37900   67000
# 17    56000  36000   69000
# 18    54000  38000   65000
# 19    54000  50000   54000
# 20    53000  39000   70000
# 21    53000  32000   70000
# 22    52000  35000   60000
# 23    52000  35000   62000
# 24    51000  38000   60000
# 25    50000  40000   60000
# 26    50000  36000   60000
# 27    50000  40000   60000
# 28    50000  39000   65000
# 29    50000  35000   70000
# ..      ...    ...     ...
# 143   32000  22900   40000
# 144   32000  28000   39000
# ...

# %% [markdown]
# **Answer**:
#
# The names of these columns are Major, Men, Median, P25th and P75th respectively.

# %% [markdown]
# **d. Set the index equal to Major.**

# %%
df538 = df538.set_index('Major')
df538
# Out:
#                                                Rank  Major_code     Total  \
# Major
# PETROLEUM ENGINEERING                             1        2419    2339.0
# MINING AND MINERAL ENGINEERING                    2        2416     756.0
# METALLURGICAL ENGINEERING                         3        2415     856.0
# NAVAL ARCHITECTURE AND MARINE ENGINEERING         4        2417    1258.0
# CHEMICAL ENGINEERING                              5        2405   32260.0
# NUCLEAR ENGINEERING                               6        2418    2573.0
# ACTUARIAL SCIENCE                                 7        6202    3777.0
# ASTRONOMY AND ASTROPHYSICS                        8        5001    1792.0
# MECHANICAL ENGINEERING                            9        2414   91227.0
# ELECTRICAL ENGINEERING                           10        2408   81527.0
# COMPUTER ENGINEERING                             11        2407   41542.0
# AEROSPACE ENGINEERING                            12        2401   15058.0
# ...

# %% [markdown]
# **e. Use the sort_values() method to sort the data by Total.**

# %%
df538.sort_values(by=['Total'])
# Out:
#                                                     Rank  Major_code  \
# Major
# MILITARY TECHNOLOGIES                                 74        3801
# MATHEMATICS AND COMPUTER SCIENCE                      53        4005
# SOIL SCIENCE                                         113        1106
# GEOLOGICAL AND GEOPHYSICAL ENGINEERING                34        2411
# MINING AND MINERAL ENGINEERING                         2        2416
# EDUCATIONAL ADMINISTRATION AND SUPERVISION           121        2301
# SCHOOL STUDENT COUNSELING                             56        2303
# METALLURGICAL ENGINEERING                              3        2415
# LIBRARY SCIENCE                                      173        3501
# COURT REPORTING                                       20        3201
# NAVAL ARCHITECTURE AND MARINE ENGINEERING              4        2417
# BOTANY                                                84        3602
# ...

# %% [markdown]
# **f. What code would you use to extract the ten majors with the greatest number of people?**

# %%
df538.sort_values(by=['Total'], ascending = False).head(10)
# Out:
#                                         Rank  Major_code     Total       Men  \
# Major
# PSYCHOLOGY                               146        5200  393735.0   86648.0
# BUSINESS MANAGEMENT AND ADMINISTRATION    77        6203  329927.0  173809.0
# BIOLOGY                                  124        3600  280709.0  111762.0
# GENERAL BUSINESS                          58        6200  234590.0  132238.0
# COMMUNICATIONS                            94        1901  213996.0   70619.0
# NURSING                                   35        6107  209394.0   21773.0
# MARKETING AND MARKETING RESEARCH          78        6206  205211.0   78857.0
# ACCOUNTING                                41        6201  198633.0   94519.0
# ENGLISH LANGUAGE AND LITERATURE          138        3301  194673.0   58227.0
# POLITICAL SCIENCE AND GOVERNMENT          79        5506  182621.0   93880.0
#
#                                            Women               Major_category  \
# Major
# ...

# %% [markdown]
# **g. Challenging. Construct horizontal bar charts of the top ten majors sorted, first, by median salary and, second, by the salary of the 25th percentile. In each case plot just the variable you sorted on.**

# %%
t = df538.sort_values(by=['Total'], ascending = False).head(10)
t["Median"].plot(kind='barh', y = "Median Salary")

plt.show()

# %%
t["P25th"].plot(kind='barh', y = "25th Percentile Salary")

plt.show()
